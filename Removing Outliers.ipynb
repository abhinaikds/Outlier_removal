# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('D:\\Codebasics\\SOCR-HeightWeight.csv')

# %%
df
# Out:
#        Index  Height(Inches)
# 0          1        65.78331
# 1          2        71.51521
# 2          3        69.39874
# 3          4        68.21660
# 4          5        67.78781
# ...      ...             ...
# 24995  24996        69.50215
# 24996  24997        64.54826
# 24997  24998        64.69855
# 24998  24999        67.52918
# 24999  25000        68.87761
#
# [25000 rows x 2 columns]

# %%
df.describe()
# Out:
#               Index  Height(Inches)
# count  25000.000000    25000.000000
# mean   12500.500000       67.993114
# std     7217.022701        1.901679
# min        1.000000       60.278360
# 25%     6250.750000       66.704397
# 50%    12500.500000       67.995700
# 75%    18750.250000       69.272958
# max    25000.000000       75.152800

# %%
sns.histplot(data=df['Height(Inches)'],kde=True)
# Out:
# <AxesSubplot: xlabel='Height(Inches)', ylabel='Count'>

# %%
sns.boxplot(df['Height(Inches)'])
# Out:
# <AxesSubplot: >

# %%
mean=df['Height(Inches)'].mean()

# %%
mean
# Out:
# 67.99311359679999

# %%
std_deviation=df['Height(Inches)'].std()

# %%
std_deviation
# Out:
# 1.901678771205604

# %%
mean-3*std_deviation
# Out:
# 62.28807728318317

# %%
mean+3*std_deviation
# Out:
# 73.6981499104168

# %%
df_no_outlierleft=df['Height(Inches)']< 62.288

# %%
mean-3*std_deviation
# Out:
# 62.28807728318317

# %%
df[df_no_outlierleft]
# Out:
#        Index  Height(Inches)
# 412      413        62.01666
# 2651    2652        60.61265
# 3696    3697        61.89340
# 5641    5642        60.86340
# 6405    6406        62.23548
# 6481    6482        61.59011
# 6941    6942        61.40550
# 9876    9877        61.30021
# 10240  10241        61.93152
# 12031  12032        60.86977
# 13971  13972        60.27836
# 14106  14107        61.90725
# 19198  19199        61.82700
# 19750  19751        62.05222
# 20608  20609        60.80620
# 22507  22508        61.57720
# 22945  22946        61.92639
# 24244  24245        62.26498

# %%
df_no_outlierright=df['Height(Inches)']> 73.69

# %%
df[df_no_outlierright]
# Out:
#        Index  Height(Inches)
# 138      139        73.90107
# 174      175        73.83364
# 1162    1163        74.24899
# 1383    1384        74.19488
# 1893    1894        75.15280
# 2395    2396        73.99549
# 2481    2482        75.11519
# 4191    4192        74.03777
# 4508    4509        74.28376
# 6627    6628        73.72628
# 7269    7270        73.81695
# 7839    7840        73.85521
# 8472    8473        73.95409
# 8828    8829        74.27270
# 9225    9226        73.75335
# 9492    9493        74.05895
# 10330  10331        74.36328
# 10635  10636        73.88574
# 11173  11174        74.16797
# 13681  13682        74.74047
# 14063  14064        74.04804
# 15209  15210        74.59993
# 15966  15967        74.25069
# 16145  16146        74.47517
# 16385  16386        73.88318
# 16752  16753        74.84890
# 17079  17080        74.29570
# 19005  19006        74.01942
# 21949  21950        74.42744
# 22471  22472        74.51784
# 22769  22770        74.19842
# ...

# %%
no_outlier=df[(df_no_outlierleft) | (df_no_outlierright)]

# %%
no_outlier
# Out:
#        Index  Height(Inches)
# 138      139        73.90107
# 174      175        73.83364
# 412      413        62.01666
# 1162    1163        74.24899
# 1383    1384        74.19488
# 1893    1894        75.15280
# 2395    2396        73.99549
# 2481    2482        75.11519
# 2651    2652        60.61265
# 3696    3697        61.89340
# 4191    4192        74.03777
# 4508    4509        74.28376
# 5641    5642        60.86340
# 6405    6406        62.23548
# 6481    6482        61.59011
# 6627    6628        73.72628
# 6941    6942        61.40550
# 7269    7270        73.81695
# 7839    7840        73.85521
# 8472    8473        73.95409
# 8828    8829        74.27270
# 9225    9226        73.75335
# 9492    9493        74.05895
# 9876    9877        61.30021
# 10240  10241        61.93152
# 10330  10331        74.36328
# 10635  10636        73.88574
# 11173  11174        74.16797
# 12031  12032        60.86977
# 13681  13682        74.74047
# 13971  13972        60.27836
# ...

# %%
df_result = df[df.isin(no_outlier)].dropna()

# %%
no_outlier
# Out:
#        Index  Height(Inches)
# 138      139        73.90107
# 174      175        73.83364
# 412      413        62.01666
# 1162    1163        74.24899
# 1383    1384        74.19488
# 1893    1894        75.15280
# 2395    2396        73.99549
# 2481    2482        75.11519
# 2651    2652        60.61265
# 3696    3697        61.89340
# 4191    4192        74.03777
# 4508    4509        74.28376
# 5641    5642        60.86340
# 6405    6406        62.23548
# 6481    6482        61.59011
# 6627    6628        73.72628
# 6941    6942        61.40550
# 7269    7270        73.81695
# 7839    7840        73.85521
# 8472    8473        73.95409
# 8828    8829        74.27270
# 9225    9226        73.75335
# 9492    9493        74.05895
# 9876    9877        61.30021
# 10240  10241        61.93152
# 10330  10331        74.36328
# 10635  10636        73.88574
# 11173  11174        74.16797
# 12031  12032        60.86977
# 13681  13682        74.74047
# 13971  13972        60.27836
# ...

# %%
df
# Out:
#        Index  Height(Inches)
# 0          1        65.78331
# 1          2        71.51521
# 2          3        69.39874
# 3          4        68.21660
# 4          5        67.78781
# ...      ...             ...
# 24995  24996        69.50215
# 24996  24997        64.54826
# 24997  24998        64.69855
# 24998  24999        67.52918
# 24999  25000        68.87761
#
# [25000 rows x 2 columns]

# %%
no_outlier.index
# Out:
# Int64Index([  138,   174,   412,  1162,  1383,  1893,  2395,  2481,  2651,
#              3696,  4191,  4508,  5641,  6405,  6481,  6627,  6941,  7269,
#              7839,  8472,  8828,  9225,  9492,  9876, 10240, 10330, 10635,
#             11173, 12031, 13681, 13971, 14063, 14106, 15209, 15966, 16145,
#             16385, 16752, 17079, 19005, 19198, 19750, 20608, 21949, 22471,
#             22507, 22769, 22945, 23039, 24244, 24801],
#            dtype='int64')

# %%
df1=df.copy()

# %%
df1.head()
# Out:
#    Index  Height(Inches)
# 0      1        65.78331
# 1      2        71.51521
# 2      3        69.39874
# 3      4        68.21660
# 4      5        67.78781

# %%
df1
# Out:
#        Index  Height(Inches)
# 0          1        65.78331
# 1          2        71.51521
# 2          3        69.39874
# 3          4        68.21660
# 4          5        67.78781
# ...      ...             ...
# 24995  24996        69.50215
# 24996  24997        64.54826
# 24997  24998        64.69855
# 24998  24999        67.52918
# 24999  25000        68.87761
#
# [24949 rows x 2 columns]

# %%
sns.histplot(data=df1['Height(Inches)'],kde=True)
# Out:
# <AxesSubplot: xlabel='Height(Inches)', ylabel='Count'>

# %%
#df1 is my new dataset which has no outliers
